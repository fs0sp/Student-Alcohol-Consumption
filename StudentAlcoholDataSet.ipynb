# %% [markdown]
# ## Alcohol Effect on Students Marks

# %%
import pandas as pd
import numpy as np

maths = pd.read_csv('student-mat.csv')
port = pd.read_csv('student-por.csv')

# %%
maths
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %%
maths.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        6   5   6   6
# ...

# %% [markdown]
# ### Data Dictionary
#
# - Address: U- Urban, R- Rural
#
# #### Total rows and columns
#
# Rows : 395, Col : 33

# %%
maths.shape
# Out:
# (395, 33)

# %%
 # To check if any missing features

maths.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
# school        395 non-null object
# sex           395 non-null object
# age           395 non-null int64
# address       395 non-null object
# famsize       395 non-null object
# Pstatus       395 non-null object
# Medu          395 non-null int64
# Fedu          395 non-null int64
# Mjob          395 non-null object
# Fjob          395 non-null object
# reason        395 non-null object
# guardian      395 non-null object
# traveltime    395 non-null int64
# studytime     395 non-null int64
# failures      395 non-null int64
# schoolsup     395 non-null object
# famsup        395 non-null object
# paid          395 non-null object
# activities    395 non-null object
# nursery       395 non-null object
# higher        395 non-null object
# internet      395 non-null object
# romantic      395 non-null object
# famrel        395 non-null int64
# ...

# %%
maths.isnull().sum()

# NO MISSING DATA
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
#BOYS  COUNT 

len(maths[maths['sex'] == 'M'])

# WE HAV 187 Boys
# Out:
# 187

# %%
#FEMALE COUNT 

len(maths[maths['sex'] == 'F' ])

#WE HAVE 208 Girls
# Out:
# 208

# %% [markdown]
# ##### There are no missing values

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set() # to make it default

# %%
def bar_chart(feature):
    female = maths[maths['sex'] == 'F' ][feature].value_counts()
    male = maths[maths['sex'] == 'M' ][feature].value_counts()
    df = pd.DataFrame([female,male])
    df.index = ['Female','Male']
    df.plot(kind='bar',stacked=True,figsize=(10,5))

# %%
bar_chart('sex')

# %% [markdown]
# ##### There are more number of Female Students then Male Students

# %% [markdown]
# #### StudyTime
# - 1 : Less than 2 hours
# - 2 : 2 to 5 hours
# - 3 : 5 to 10 Hours
# - 4 : Greater than 10 hours

# %%
sns.distplot(maths['studytime'],kde=False)
# Out:
# C:\Users\Shivam\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
bar_chart('age')

# %%
bar_chart('Dalc')

# %%
bar_chart('Walc')

# %%
bar_chart('G1')

# %%
sns.countplot(x='Dalc',data=maths)

# %%
graph = sns.factorplot("Dalc","G1","sex",data=maths,kind="bar" ,legend=True)

plt.show()
# Out:
# C:\Users\Shivam\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\Shivam\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
graph = sns.factorplot("Dalc","G2","sex",data=maths,kind="bar" ,legend=True)

plt.show()
# Out:
# C:\Users\Shivam\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\Shivam\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
graph = sns.factorplot("Dalc","G3","sex",data=maths,kind="bar" ,legend=True)

plt.show()
# Out:
# C:\Users\Shivam\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\Shivam\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
maths[maths['Dalc'] == 5]['G3']
# Out:
# 29     11
# 61     11
# 66     12
# 100     5
# 223    13
# 236    13
# 247     8
# 327    10
# 349    13
# Name: G3, dtype: int64

# %%
G3 = maths['G3']
G2 = maths['G2']
G1 = maths['G1']
workday = maths['Dalc']
weekend = maths['Walc']
healthdata = maths['health']

# %% [markdown]
# ###  Alcohol Consumption VS Marks in G1

# %%
fig, axes = plt.subplots(1, 2, figsize=(15,5))

axes[0].bar(G1, workday, align="center", width=0.5, alpha=0.5)
axes[0].set_title("WORKDAY / G1 Marks")

axes[1].bar(G1, weekend, align="center", width=0.5, alpha=0.5)
axes[1].set_title("WEEKEND / G1 Marks")
# Out:
# Text(0.5, 1.0, 'WEEKEND / G1 Marks')

# %%
# axax = maths[(maths['Dalc'] == 1) & (maths['G1'] < 6)]['health']

# sns.countplot(x=axax,data=maths)

# %%
fig, axes = plt.subplots(1, 2, figsize=(14,5))

axes[0].bar(G2, workday, align="center", width=0.5, alpha=0.5)
axes[0].set_title("WORKDAY / G1 Marks")

axes[1].bar(G2, weekend, align="center", width=0.5, alpha=0.5)
axes[1].set_title("WEEKEND / G1 Marks")
# Out:
# Text(0.5, 1.0, 'WEEKEND / G1 Marks')

# %%
fig, axes = plt.subplots(1, 2, figsize=(14,5))

axes[0].bar(G3, workday, align="center", width=0.5, alpha=0.5)
axes[0].set_title("WORKDAY / G3 Marks")

axes[1].bar(G3, weekend, align="center", width=0.5, alpha=0.5)
axes[1].set_title("WEEKEND / G3 Marks")
# Out:
# Text(0.5, 1.0, 'WEEKEND / G3 Marks')

# %%
sex_mapping = {"M": 0, "F": 1}
for i in maths:
    i['sex'] = i['sex'].map(sex_mapping)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-710f7337ff4a> in <module>()
#       1 sex_mapping = {"M": 0, "F": 1}
#       2 for i in maths:
# ----> 3     i['sex'] = i['sex'].map(sex_mapping)
#
# TypeError: string indices must be integers
